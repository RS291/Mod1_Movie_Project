# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from urllib.request import urlopen


def get_table_after_1996(url):
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    website_url = requests.get(url).text
    soup = BeautifulSoup(website_url, 'lxml')
    My_table = soup.find('table',{'class':'wikitable sortable'})
    titles = []
    directors = []
    actors = []
    genres = []
    rows = My_table.find_all('tr')
    for row in rows:
        cells = row.find_all('td')
        if len(cells)>=1:
                title = cells[0]
                titles.append(title.text)
                director = cells[1]
                directors.append(director.text)
                actor = cells[2]
                actors.append(actor.text)
                genre = cells[3]
                genres.append(genre.text)
                index = [*range(1,len(titles)+1,1)]
    return pd.DataFrame({'Titles': titles,'Directors' : directors, 'Actors': actors, 'Genres': genres, }, index = index )
    
df_1999 = get_table_after_1996('https://en.wikipedia.org/wiki/List_of_American_films_of_1999')
df_1999.head(10)
# Out:
#                                   Titles                Directors  \
# 1             10 Things I Hate About You               Gil Junger
# 2                       The 13th Warrior           John McTiernan
# 3                         200 Cigarettes       Risa Bramon Garcia
# 4                          The 4th Floor            Josh Klausner
# 5                                    8mm          Joel Schumacher
# 6   The Adventures of Elmo in Grouchland           Gary Halvorson
# 7                        American Beauty               Sam Mendes
# 8                         American Movie              Chris Smith
# 9                           American Pie  Paul Weitz, Chris Weitz
# 10                          Analyze This             Harold Ramis
#
#                                                Actors           Genres
# 1   Julia Stiles, Heath Ledger, Larisa Oleynik, Jo...  Romantic comedy
# 2   Antonio Banderas, Diane Venora, Vladimir Kulic...           Action
# 3   Ben Affleck, Casey Affleck, Dave Chappelle, Gu...    Comedy, Drama
# 4        Juliette Lewis, William Hurt, Shelley Duvall           Horror
# 5   Nicolas Cage, Joaquin Phoenix, James Gandolfin...         Thriller
# 6    Kevin Clash, Mandy Patinkin, Vanessa L. Williams  Children's film
# 7   Kevin Spacey, Annette Bening, Chris Cooper, We...            Drama
# 8                       Mark Borchardt, Tom Schimmels      Documentary
# 9   Jason Biggs, Seann William Scott, Tara Reid, S...           Comedy
# 10         Robert De Niro, Billy Crystal, Lisa Kudrow           Comedy
